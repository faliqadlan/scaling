# %% [markdown]
# # Import Required Libraries
# Import the necessary libraries, including NumPy, OpenCV, and Matplotlib.

# %%
# Import Required Libraries
# %pip install opencv-python matplotlib numpy
import numpy as np
import cv2
import matplotlib.pyplot as plt
# Out:
# Requirement already satisfied: opencv-python in d:\onedrive - ugm 365\x-ray\scaling\.conda\lib\site-packages (4.10.0.84)
# Requirement already satisfied: matplotlib in d:\onedrive - ugm 365\x-ray\scaling\.conda\lib\site-packages (3.9.2)
# Requirement already satisfied: numpy in d:\onedrive - ugm 365\x-ray\scaling\.conda\lib\site-packages (2.1.3)
# Requirement already satisfied: contourpy>=1.0.1 in d:\onedrive - ugm 365\x-ray\scaling\.conda\lib\site-packages (from matplotlib) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in d:\onedrive - ugm 365\x-ray\scaling\.conda\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in d:\onedrive - ugm 365\x-ray\scaling\.conda\lib\site-packages (from matplotlib) (4.54.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in d:\onedrive - ugm 365\x-ray\scaling\.conda\lib\site-packages (from matplotlib) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in d:\onedrive - ugm 365\x-ray\scaling\.conda\lib\site-packages (from matplotlib) (24.1)
# Requirement already satisfied: pillow>=8 in d:\onedrive - ugm 365\x-ray\scaling\.conda\lib\site-packages (from matplotlib) (11.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in d:\onedrive - ugm 365\x-ray\scaling\.conda\lib\site-packages (from matplotlib) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in d:\onedrive - ugm 365\x-ray\scaling\.conda\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in d:\onedrive - ugm 365\x-ray\scaling\.conda\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # Load X-ray Images
# Load the X-ray images from the specified directory or file paths.

# %%
import os
import cv2
import matplotlib.pyplot as plt


def load_xray_images(directory):
    """
    Load X-ray images from the specified directory.

    Parameters:
    directory (str): The path to the directory containing X-ray images.

    Returns:
    list: A list of loaded X-ray images.
    """
    images = []
    for filename in os.listdir(directory):
        if (
            filename.endswith(".png")
            or filename.endswith(".jpg")
            or filename.endswith(".jpeg")
            or filename.endswith(".tiff")
        ):
            img_path = os.path.join(directory, filename)
            img = cv2.imread(img_path, cv2.IMREAD_GRAYSCALE)
            if img is not None:
                images.append(img)
    return images


# Example usage
directory = "./images"  # Replace with the actual path to your X-ray images
xray_images = load_xray_images(directory)

# Display the first loaded image
if xray_images:
    plt.imshow(xray_images[0], cmap="gray")
    plt.title("First Loaded X-ray Image")
    plt.axis("off")
    plt.show()

# %% [markdown]
# # Preprocess Images
# Convert the images to grayscale if they are not already, and resize them to a standard size.

# %%
# Preprocess Images

# Function to preprocess images: convert to grayscale if not already, and resize to a standard size
def preprocess_images(images):
    """
    Preprocess the X-ray images by converting them to grayscale and resizing them to a standard size.
    
    Parameters:
    images (list): A list of X-ray images.
    target_size (tuple): The target size for resizing the images (width, height).
    
    Returns:
    list: A list of preprocessed X-ray images.
    """
    preprocessed_images = []
    for img in images:
        # Check if the image is already in grayscale
        if len(img.shape) == 3 and img.shape[2] == 3:
            img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
        
        preprocessed_images.append(img)
    
    return preprocessed_images

# Example usage
preprocessed_xray_images = preprocess_images(xray_images)

# Display the first preprocessed image
if preprocessed_xray_images:
    plt.imshow(preprocessed_xray_images[0], cmap='gray')
    plt.title('First Preprocessed X-ray Image')
    plt.axis('off')
    plt.show()

# %% [markdown]
# # Apply Histogram Equalization
# Use histogram equalization to adjust the contrast of the images so that they have similar gray levels.

# %%
# Apply Histogram Equalization

def apply_histogram_equalization(images):
    """
    Apply histogram equalization to adjust the contrast of the X-ray images.
    
    Parameters:
    images (list): A list of X-ray images.
    
    Returns:
    list: A list of X-ray images with equalized histograms.
    """
    equalized_images = []
    for img in images:
        equalized_img = cv2.equalizeHist(img)
        equalized_images.append(equalized_img)
    
    return equalized_images

# Example usage
equalized_xray_images = apply_histogram_equalization(preprocessed_xray_images)

# Display the first equalized image
if equalized_xray_images:
    plt.imshow(equalized_xray_images[0], cmap='gray')
    plt.title('First Equalized X-ray Image')
    plt.axis('off')
    plt.show()

# %%
# Apply CLAHE (Contrast Limited Adaptive Histogram Equalization)
def apply_clahe(images, clip_limit=2.0, tile_grid_size=(8, 8)):
    """
    Apply CLAHE to adjust the contrast of the X-ray images.

    Parameters:
    images (list): A list of X-ray images.
    clip_limit (float): Threshold for contrast limiting.
    tile_grid_size (tuple): Size of grid for histogram equalization.

    Returns:
    list: A list of X-ray images with CLAHE applied.
    """
    clahe = cv2.createCLAHE(clipLimit=clip_limit, tileGridSize=tile_grid_size)
    clahe_images = []
    for img in images:
        clahe_img = clahe.apply(img)
        clahe_images.append(clahe_img)

    return clahe_images


# Example usage
clahe_xray_images = apply_clahe(preprocessed_xray_images)

# Display the first CLAHE image
if clahe_xray_images:
    plt.imshow(clahe_xray_images[0], cmap="gray")
    plt.title("First CLAHE X-ray Image")
    plt.axis("off")
    plt.show()

# %% [markdown]
# # Display Results
# Display the original and processed images side by side for comparison.

# %%
# Display Results


# Function to display original and processed images closer together
def display_results(original_images, processed_images, num_images=5):
    """
    Display the original and processed X-ray images closer together for comparison.

    Parameters:
    original_images (list): A list of original X-ray images.
    processed_images (list): A list of processed X-ray images.
    num_images (int): The number of images to display for comparison.
    """
    plt.figure(figsize=(15, 5))
    for i in range(min(num_images, len(original_images), len(processed_images))):
        # Display original image
        plt.subplot(2, num_images, i + 1)
        plt.imshow(original_images[i], cmap="gray")
        plt.title(f"Original Image {i+1}")
        plt.axis("off")

        # Display processed image
        plt.subplot(2, num_images, num_images + i + 1)
        plt.imshow(processed_images[i], cmap="gray")
        plt.title(f"Processed Image {i+1}")
        plt.axis("off")

    plt.tight_layout()
    plt.show()


# Example usage
display_results(xray_images, equalized_xray_images)

# %% [markdown]
# # Using Clahe

# %%
# Import Required Libraries
# %pip install opencv-python matplotlib numpy
import numpy as np
import cv2
import matplotlib.pyplot as plt
import os

# Load X-ray Images
def load_xray_images(directory):
    """
    Load X-ray images from the specified directory.

    Parameters:
    directory (str): The path to the directory containing X-ray images.

    Returns:
    list: A list of loaded X-ray images.
    """
    images = []
    for filename in os.listdir(directory):
        if filename.endswith((".png", ".jpg", ".jpeg", ".tiff")):
            img_path = os.path.join(directory, filename)
            img = cv2.imread(img_path, cv2.IMREAD_GRAYSCALE)
            if img is not None:
                images.append(img)
    return images

# Example usage
directory = "./images"  # Replace with the actual path to your X-ray images
xray_images = load_xray_images(directory)

# Display the first loaded image
if xray_images:
    plt.imshow(xray_images[0], cmap="gray")
    plt.title("First Loaded X-ray Image")
    plt.axis("off")
    plt.show()

# Preprocess Images
def preprocess_images(images):
    """
    Preprocess the X-ray images by converting them to grayscale and resizing them to a standard size.
    
    Parameters:
    images (list): A list of X-ray images.
    
    Returns:
    list: A list of preprocessed X-ray images.
    """
    preprocessed_images = []
    for img in images:
        # Check if the image is already in grayscale
        if len(img.shape) == 3 and img.shape[2] == 3:
            img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
        preprocessed_images.append(img)
    return preprocessed_images

# Example usage
preprocessed_xray_images = preprocess_images(xray_images)

# Display the first preprocessed image
if preprocessed_xray_images:
    plt.imshow(preprocessed_xray_images[0], cmap='gray')
    plt.title('First Preprocessed X-ray Image')
    plt.axis('off')
    plt.show()

# Apply CLAHE (Contrast Limited Adaptive Histogram Equalization)
def apply_clahe(images, clip_limit=2.0, tile_grid_size=(8, 8)):
    """
    Apply CLAHE to adjust the contrast of the X-ray images.
    
    Parameters:
    images (list): A list of X-ray images.
    clip_limit (float): Threshold for contrast limiting.
    tile_grid_size (tuple): Size of grid for histogram equalization.
    
    Returns:
    list: A list of X-ray images with CLAHE applied.
    """
    clahe = cv2.createCLAHE(clipLimit=clip_limit, tileGridSize=tile_grid_size)
    clahe_images = []
    for img in images:
        clahe_img = clahe.apply(img)
        clahe_images.append(clahe_img)
    
    return clahe_images

# Example usage
clahe_xray_images = apply_clahe(preprocessed_xray_images)

# Display the first CLAHE image
if clahe_xray_images:
    plt.imshow(clahe_xray_images[0], cmap='gray')
    plt.title('First CLAHE X-ray Image')
    plt.axis('off')
    plt.show()

# Display Results
def display_results(original_images, processed_images, num_images=5):
    """
    Display the original and processed X-ray images closer together for comparison.

    Parameters:
    original_images (list): A list of original X-ray images.
    processed_images (list): A list of processed X-ray images.
    num_images (int): The number of images to display for comparison.
    """
    plt.figure(figsize=(15, 5))
    for i in range(min(num_images, len(original_images), len(processed_images))):
        # Display original image
        plt.subplot(2, num_images, i + 1)
        plt.imshow(original_images[i], cmap="gray")
        plt.title(f"Original Image {i+1}")
        plt.axis("off")

        # Display processed image
        plt.subplot(2, num_images, num_images + i + 1)
        plt.imshow(processed_images[i], cmap="gray")
        plt.title(f"Processed Image {i+1}")
        plt.axis("off")

    plt.tight_layout()
    plt.show()

# Example usage
display_results(xray_images, clahe_xray_images)
# Out:
# Requirement already satisfied: opencv-python in d:\onedrive - ugm 365\x-ray\scaling\.conda\lib\site-packages (4.10.0.84)
# Requirement already satisfied: matplotlib in d:\onedrive - ugm 365\x-ray\scaling\.conda\lib\site-packages (3.9.2)
# Requirement already satisfied: numpy in d:\onedrive - ugm 365\x-ray\scaling\.conda\lib\site-packages (2.1.3)
# Requirement already satisfied: contourpy>=1.0.1 in d:\onedrive - ugm 365\x-ray\scaling\.conda\lib\site-packages (from matplotlib) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in d:\onedrive - ugm 365\x-ray\scaling\.conda\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in d:\onedrive - ugm 365\x-ray\scaling\.conda\lib\site-packages (from matplotlib) (4.54.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in d:\onedrive - ugm 365\x-ray\scaling\.conda\lib\site-packages (from matplotlib) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in d:\onedrive - ugm 365\x-ray\scaling\.conda\lib\site-packages (from matplotlib) (24.1)
# Requirement already satisfied: pillow>=8 in d:\onedrive - ugm 365\x-ray\scaling\.conda\lib\site-packages (from matplotlib) (11.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in d:\onedrive - ugm 365\x-ray\scaling\.conda\lib\site-packages (from matplotlib) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in d:\onedrive - ugm 365\x-ray\scaling\.conda\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in d:\onedrive - ugm 365\x-ray\scaling\.conda\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
